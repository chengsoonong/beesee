# %% [markdown]
# # Bees dataset
#
# * Images from Tanya Latty
# * Labels from Jakub Nabaglo

# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exploring the raw labels

# %%
label_data = json.load(open('labels.json','r'))
label_data['comment']
# Out:
# 'Origin of coordinates is in the bottom left. Parts of bee that are not visible are marked with null.'

# %%
label_data.keys()
# Out:
# dict_keys(['labelled', 'comment', 'unlabelled'])

# %%
print('%d labelled, %d unlabelled examples' % (len(label_data['labelled']), len(label_data['unlabelled'])))
# Out:
# 640 labelled, 0 unlabelled examples

# %%
label_list = label_data['labelled']
label_list[0].keys()
# Out:
# dict_keys(['head', 'left antenna', 'difficult', 'size', 'right wing', 'path', 'thorax', 'right antenna', 'abdomen', 'left wing'])

# %% [markdown]
# ## Convert to pandas dataframe

# %%
tuples = ['size', 'head', 'thorax', 'abdomen', 'left antenna', 'right antenna', 'left wing', 'right wing']
coords = ['x', 'y']
col_pairs = []
for tup in tuples:
    for c in coords:
        col_pairs.append('%s_%s' % (tup, c))
col_names = ['path', 'species', 'is_difficult'] + col_pairs
num_labels = len(label_list)

# %%
labels = pd.DataFrame(index=range(num_labels), columns=col_names)
for ix,lab in enumerate(label_list):
    path = lab['path']
    labels['path'].ix[ix] = path
    labels['species'].ix[ix] = path.split('/')[0]
    labels['is_difficult'].ix[ix] = not 'difficult' in lab
    for key in tuples:
        if lab[key] is not None:
            labels['%s_x' % key].ix[ix] = lab[key][0]
            labels['%s_y' % key].ix[ix] = lab[key][1]
        else:
            labels['%s_x' % key].ix[ix] = np.nan
            labels['%s_y' % key].ix[ix] = np.nan
labels.head(10)
# Out:
#                                                 path                 species  \
# 0  Afranthidium repetitum/Addison Rd Haphazard Ta...  Afranthidium repetitum
# 1  Afranthidium repetitum/Balgowlah box 2 cell b2...  Afranthidium repetitum
# 2  Afranthidium repetitum/Balgowlah box 2 cell b2...  Afranthidium repetitum
# 3  Afranthidium repetitum/Balgowlah box 2 cell c2...  Afranthidium repetitum
# 4  Afranthidium repetitum/Balgowlah box 2 cell c2...  Afranthidium repetitum
# 5  Afranthidium repetitum/Balgowlah box 2 cell c2...  Afranthidium repetitum
# 6  Afranthidium repetitum/Balgowlah box 2 cell c2...  Afranthidium repetitum
# 7  Afranthidium repetitum/Balgowlah Haphazard Ali...  Afranthidium repetitum
# 8  Afranthidium repetitum/Balgowlah Haphazard Jam...  Afranthidium repetitum
# 9  Afranthidium repetitum/Balgowlah Haphazard Jam...  Afranthidium repetitum
#
#   is_difficult size_x size_y    head_x    head_y  thorax_x  thorax_y  \
# 0        False    427    285  233.7278  134.3201  206.9032  146.0612
# 1        False    427    285  243.3961     142.5  223.7689  142.4641
# 2        False    427    285  241.7249  98.80314  211.7374  127.0117
# 3        False    427    285  234.6417  148.3167  220.7953  157.6227
# 4        False    427    285  249.9113  73.61387  226.0669  88.08048
# 5        False    427    285  246.1315  150.0924  219.7802  153.6568
# 6         True    427    285   183.284  139.4448  201.6055  134.6106
# 7        False    427    285  184.7365  137.0424  199.9245  144.9644
# 8        False    427    285  174.6634  151.2903  207.3439  149.6191
# 9        False    427    285  198.4034  173.4276  223.6318  173.4276
#
#   abdomen_x abdomen_y left antenna_x left antenna_y right antenna_x  \
# 0  183.6006  167.7252       221.2229       96.08085        281.4559
# 1  187.1618  133.4845       266.3332       161.5821        270.9878
# 2  170.3352  124.1034       251.3965       131.6664        236.0943
# 3  177.2845  148.3526        258.855       166.0539        266.4148
# 4  174.0857    88.952       294.9138       98.51263        283.0292
# 5  166.3073  139.7353       262.4554       124.6126        243.3341
# 6  221.3078  123.3069       174.3403       129.1595             NaN
# 7  221.4841  150.7452            NaN            NaN        174.8103
# 8  254.7814  129.8417       156.1199       140.3489             NaN
# 9  262.4913  153.6535       189.6784       177.8635        168.6313
#
#   right antenna_y left wing_x left wing_y right wing_x right wing_y
# 0        118.2541    132.8173    134.8652          NaN          NaN
# 1        141.0083         NaN         NaN     162.1912     145.9534
# 2        127.0117     187.276    173.6169     148.8899     102.4785
# 3        148.8977         NaN         NaN     159.4004     161.1121
# 4        50.27536    173.2109    140.6068     159.8704     59.25171
# 5        117.6339         NaN         NaN     144.4572     141.9125
# 6             NaN         NaN         NaN     242.6095     140.3522
# 7        147.0012    237.3673    162.0129     223.7722     167.2094
# 8             NaN    294.2969    163.2501     292.6257     180.4096
# 9        159.8717    287.7915    204.7991     261.7666     210.6517

# %%
labels.to_csv('labels.csv', index=False)

# %% [markdown]
# ## Statistics about labels

# %%
labels.groupby('species').count()
# Out:
#                                     path  is_difficult  size_x  size_y  \
# species
# Afranthidium repetitum               123           123     123     123
# Amegilla bombiformis                   2             2       2       2
# Amegilla sp                          109           109     109     109
# Amphylaeus obscuriceps                 1             1       1       1
# Exoneura sp                            3             3       3       3
# Homalictus sp                         47            47      47      47
# Homalictus urbanus                     2             2       2       2
# Homalictus urbanus male (possibly)     6             6       6       6
# Hylaeus alcyoneus                      6             6       6       6
# Hylaeus euxanthus                      2             2       2       2
# Hylaeus honestus                      81            81      81      81
# Hylaeus nubilosus                      7             7       7       7
# Hyleoides concinna                     7             7       7       7
# Lasioglossum lanarium                  2             2       2       2
# Lassioglossum or Lipotriches           1             1       1       1
# Leoproctus amarbilis (maybe)           1             1       1       1
# Lipotriches australica                 3             3       3       3
# Lipotriches flavoviridis               7             7       7       7
# Lipotriches muscosa                    3             3       3       3
# Lipotriches phanerura                 63            63      63      63
# Megachile apicata                      1             1       1       1
# Megachile aurifrons                   14            14      14      14
# Megachile erythropyga                 19            19      19      19
# Megachile ferox                        2             2       2       2
# Megachile lucideventris                7             7       7       7
# Megachile maculariformis               1             1       1       1
# Megachile mystaceana                   1             1       1       1
# Megachile serricauda                 112           112     112     112
# Tetragonula carbonaria                 4             4       4       4
# Thyreus caeruleopunctatus              1             1       1       1
# Unknown species                        2             2       2       2
#
#                                     head_x  head_y  thorax_x  thorax_y  \
# species
# Afranthidium repetitum                 122     122       121       121
# Amegilla bombiformis                     2       2         2         2
# Amegilla sp                            100     100       109       109
# Amphylaeus obscuriceps                   1       1         1         1
# Exoneura sp                              3       3         3         3
# Homalictus sp                           47      47        47        47
# Homalictus urbanus                       2       2         2         2
# Homalictus urbanus male (possibly)       6       6         6         6
# Hylaeus alcyoneus                        6       6         6         6
# Hylaeus euxanthus                        2       2         1         1
# Hylaeus honestus                        81      81        79        79
# Hylaeus nubilosus                        7       7         7         7
# Hyleoides concinna                       7       7         7         7
# Lasioglossum lanarium                    2       2         2         2
# Lassioglossum or Lipotriches             1       1         1         1
# Leoproctus amarbilis (maybe)             1       1         1         1
# Lipotriches australica                   3       3         3         3
# Lipotriches flavoviridis                 7       7         7         7
# Lipotriches muscosa                      3       3         3         3
# Lipotriches phanerura                   63      63        63        63
# Megachile apicata                        1       1         1         1
# Megachile aurifrons                     14      14        14        14
# Megachile erythropyga                   19      19        19        19
# Megachile ferox                          2       2         2         2
# Megachile lucideventris                  7       7         7         7
# Megachile maculariformis                 1       1         1         1
# Megachile mystaceana                     1       1         1         1
# Megachile serricauda                   112     112       112       112
# Tetragonula carbonaria                   3       3         3         3
# Thyreus caeruleopunctatus                1       1         1         1
# Unknown species                          2       2         2         2
#
#                                     abdomen_x  abdomen_y  left antenna_x  \
# species
# Afranthidium repetitum                    119        119             106
# Amegilla bombiformis                        2          2               2
# Amegilla sp                               108        108              96
# Amphylaeus obscuriceps                      1          1               1
# Exoneura sp                                 3          3               3
# Homalictus sp                              47         47              43
# Homalictus urbanus                          2          2               2
# Homalictus urbanus male (possibly)          6          6               6
# Hylaeus alcyoneus                           6          6               6
# Hylaeus euxanthus                           1          1               2
# Hylaeus honestus                           66         66              69
# Hylaeus nubilosus                           7          7               5
# Hyleoides concinna                          7          7               7
# Lasioglossum lanarium                       2          2               1
# Lassioglossum or Lipotriches                1          1               1
# Leoproctus amarbilis (maybe)                1          1               1
# Lipotriches australica                      3          3               2
# Lipotriches flavoviridis                    7          7               5
# Lipotriches muscosa                         3          3               3
# Lipotriches phanerura                      63         63              60
# Megachile apicata                           1          1               1
# Megachile aurifrons                        14         14              11
# Megachile erythropyga                      19         19              14
# Megachile ferox                             2          2               2
# Megachile lucideventris                     7          7               4
# Megachile maculariformis                    1          1               1
# Megachile mystaceana                        1          1               0
# Megachile serricauda                      112        112              93
# Tetragonula carbonaria                      4          4               3
# Thyreus caeruleopunctatus                   1          1               1
# Unknown species                             2          2               2
#
#                                     left antenna_y  right antenna_x  \
# species
# Afranthidium repetitum                         106               99
# Amegilla bombiformis                             2                2
# Amegilla sp                                     96              100
# Amphylaeus obscuriceps                           1                1
# Exoneura sp                                      3                3
# Homalictus sp                                   43               43
# Homalictus urbanus                               2                2
# Homalictus urbanus male (possibly)               6                6
# Hylaeus alcyoneus                                6                5
# Hylaeus euxanthus                                2                2
# Hylaeus honestus                                69               68
# Hylaeus nubilosus                                5                5
# Hyleoides concinna                               7                6
# Lasioglossum lanarium                            1                2
# Lassioglossum or Lipotriches                     1                1
# Leoproctus amarbilis (maybe)                     1                1
# Lipotriches australica                           2                2
# Lipotriches flavoviridis                         5                7
# Lipotriches muscosa                              3                3
# Lipotriches phanerura                           60               59
# Megachile apicata                                1                1
# Megachile aurifrons                             11               10
# Megachile erythropyga                           14               12
# Megachile ferox                                  2                2
# Megachile lucideventris                          4                4
# Megachile maculariformis                         1                1
# Megachile mystaceana                             0                0
# Megachile serricauda                            93               99
# Tetragonula carbonaria                           3                3
# Thyreus caeruleopunctatus                        1                0
# Unknown species                                  2                2
#
#                                     right antenna_y  left wing_x  left wing_y  \
# species
# Afranthidium repetitum                           99           98           98
# Amegilla bombiformis                              2            2            2
# Amegilla sp                                     100           96           96
# Amphylaeus obscuriceps                            1            1            1
# Exoneura sp                                       3            3            3
# Homalictus sp                                    43           40           40
# Homalictus urbanus                                2            2            2
# Homalictus urbanus male (possibly)                6            4            4
# Hylaeus alcyoneus                                 5            3            3
# Hylaeus euxanthus                                 2            2            2
# Hylaeus honestus                                 68           61           61
# Hylaeus nubilosus                                 5            5            5
# Hyleoides concinna                                6            5            5
# Lasioglossum lanarium                             2            1            1
# Lassioglossum or Lipotriches                      1            1            1
# Leoproctus amarbilis (maybe)                      1            1            1
# Lipotriches australica                            2            3            3
# Lipotriches flavoviridis                          7            6            6
# Lipotriches muscosa                               3            3            3
# Lipotriches phanerura                            59           53           53
# Megachile apicata                                 1            0            0
# Megachile aurifrons                              10           10           10
# Megachile erythropyga                            12           17           17
# Megachile ferox                                   2            2            2
# Megachile lucideventris                           4            3            3
# Megachile maculariformis                          1            1            1
# Megachile mystaceana                              0            1            1
# Megachile serricauda                             99           88           88
# Tetragonula carbonaria                            3            4            4
# Thyreus caeruleopunctatus                         0            1            1
# Unknown species                                   2            2            2
#
#                                     right wing_x  right wing_y
# species
# Afranthidium repetitum                       101           101
# Amegilla bombiformis                           1             1
# Amegilla sp                                   94            94
# Amphylaeus obscuriceps                         1             1
# Exoneura sp                                    3             3
# Homalictus sp                                 32            32
# Homalictus urbanus                             2             2
# Homalictus urbanus male (possibly)             4             4
# Hylaeus alcyoneus                              5             5
# Hylaeus euxanthus                              1             1
# Hylaeus honestus                              55            55
# Hylaeus nubilosus                              3             3
# Hyleoides concinna                             6             6
# Lasioglossum lanarium                          2             2
# Lassioglossum or Lipotriches                   1             1
# Leoproctus amarbilis (maybe)                   1             1
# Lipotriches australica                         3             3
# Lipotriches flavoviridis                       5             5
# Lipotriches muscosa                            3             3
# Lipotriches phanerura                         50            50
# Megachile apicata                              1             1
# Megachile aurifrons                           10            10
# Megachile erythropyga                         15            15
# Megachile ferox                                2             2
# Megachile lucideventris                        5             5
# Megachile maculariformis                       1             1
# Megachile mystaceana                           1             1
# Megachile serricauda                          93            93
# Tetragonula carbonaria                         3             3
# Thyreus caeruleopunctatus                      1             1
# Unknown species                                2             2

# %%
labels[['species','is_difficult']].groupby('species').agg(['sum', 'count'])
# Out:
#                                    is_difficult
#                                             sum count
# species
# Afranthidium repetitum                        9   123
# Amegilla bombiformis                          0     2
# Amegilla sp                                   6   109
# Amphylaeus obscuriceps                    False     1
# Exoneura sp                                   0     3
# Homalictus sp                                 7    47
# Homalictus urbanus                            0     2
# Homalictus urbanus male (possibly)            0     6
# Hylaeus alcyoneus                             0     6
# Hylaeus euxanthus                             0     2
# Hylaeus honestus                              9    81
# Hylaeus nubilosus                             1     7
# Hyleoides concinna                            0     7
# Lasioglossum lanarium                         0     2
# Lassioglossum or Lipotriches              False     1
# Leoproctus amarbilis (maybe)              False     1
# Lipotriches australica                        0     3
# Lipotriches flavoviridis                      0     7
# Lipotriches muscosa                           0     3
# Lipotriches phanerura                         4    63
# Megachile apicata                         False     1
# Megachile aurifrons                           1    14
# Megachile erythropyga                         1    19
# Megachile ferox                               0     2
# Megachile lucideventris                       1     7
# Megachile maculariformis                  False     1
# Megachile mystaceana                      False     1
# Megachile serricauda                          9   112
# Tetragonula carbonaria                        1     4
# Thyreus caeruleopunctatus                 False     1
# Unknown species                               0     2

# %%
big_images = np.logical_and(labels['size_x'] > 500, labels['size_y'] > 300)
is_easy = np.logical_not(labels['is_difficult'])
print('Number of big images = %d' % big_images.sum())
print('Number of difficult images = %d' % labels['is_difficult'].sum())
labels[col_pairs].ix[np.logical_and(is_easy, np.logical_not(big_images))].mean()
# Out:
# Number of big images = 59
# Number of difficult images = 49
# size_x             424.375231
# size_y             287.624769
# head_x             212.682894
# head_y             139.747535
# thorax_x           213.727282
# thorax_y           148.559299
# abdomen_x          214.748171
# abdomen_y          144.925642
# left antenna_x     219.868296
# left antenna_y     141.240267
# right antenna_x    210.696577
# right antenna_y    142.469177
# left wing_x        217.669965
# left wing_y        151.245448
# right wing_x       207.864318
# right wing_y       154.238102
# dtype: float64
